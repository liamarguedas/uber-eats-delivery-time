# %%
# Warnings
import warnings
warnings.filterwarnings('ignore')

# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Settings
pd.set_option('display.max_columns', None)
sns.set_style('whitegrid')
# %matplotlib inline

# %%
from sklearn.pipeline import Pipeline
from TransformationsPipeline import MapMissingValues, DateTime, SetDtypes, TransformStr, ImputeMissingValues, GetDistances

# %%
data = pd.read_csv('../data/uber-eats-deliveries.csv')

# %%
Pipeline = Pipeline([
    ('MapMissingValues', MapMissingValues(data = data)),
    ('DateTime', DateTime(data = data)),
    ('Dtypes', SetDtypes(data = data)),
    ('TransformStr', TransformStr(data = data)),
    ('ImputeMissingValues', ImputeMissingValues(data = data)),
    ('GetDistances', GetDistances(data = data))    
])

# %%
data_transformed = Pipeline.transform(X = data)

# %%
data_transformed
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 0      0x4607     INDORES13DEL02                 37.0
# 1      0xb379     BANGRES18DEL02                 34.0
# 2      0x5d6d     BANGRES19DEL01                 23.0
# 3      0x7a6a    COIMBRES13DEL02                 38.0
# 4      0x70a2     CHENRES12DEL01                 32.0
# ...       ...                ...                  ...
# 43857  0x7c09      JAPRES04DEL01                 30.0
# 43858  0xd641      AGRRES16DEL01                 21.0
# 43859  0x4f8d     CHENRES08DEL03                 30.0
# 43860  0x5eee    COIMBRES11DEL01                 20.0
# 43861  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          4.9            22.745049             75.892471
# 1                          4.5            12.913041             77.683237
# 2                          4.4            12.914264             77.678400
# ...
